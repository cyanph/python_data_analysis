# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
'key2' : ['one', 'two', 'one', 'two', 'one'],
'data1' : np.random.randn(5),
'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.163722 -0.103074
# 1    a  two -0.869117 -0.948556
# 2    b  one -1.768771 -0.713723
# 3    b  two  0.455637  0.137741
# 4    a  one  0.916455 -0.547168

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a    0.070353
# b   -0.656567
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()

# %%
means
# Out:
# key1  key2
# a     one     0.540089
#       two    -0.869117
# b     one    -1.768771
#       two     0.455637
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a     0.540089 -0.869117
# b    -1.768771  0.455637

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])

# %%
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005   -0.869117
#             2006   -1.768771
# Ohio        2005    0.309680
#             2006    0.916455
# Name: data1, dtype: float64

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a     0.070353 -0.532933
# b    -0.656567 -0.287991

# %%
df.groupby(['key1', 'key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.540089 -0.325121
#      two  -0.869117 -0.948556
# b    one  -1.768771 -0.713723
#      two   0.455637  0.137741

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
for name, group in df.groupby('key1'):
  print(name)
  print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.163722 -0.103074
# 1    a  two -0.869117 -0.948556
# 4    a  one  0.916455 -0.547168
# b
#   key1 key2     data1     data2
# 2    b  one -1.768771 -0.713723
# 3    b  two  0.455637  0.137741

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
 print((k1, k2))
 print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  0.163722 -0.103074
# 4    a  one  0.916455 -0.547168
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two -0.869117 -0.948556
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one -1.768771 -0.713723
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two  0.455637  0.137741

# %%
pieces = dict(list(df.groupby('key1')))

# %%
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one  0.163722 -0.103074
#  1    a  two -0.869117 -0.948556
#  4    a  one  0.916455 -0.547168, 'b':   key1 key2     data1     data2
#  2    b  one -1.768771 -0.713723
#  3    b  two  0.455637  0.137741}

# %%
list(df.groupby('key1'))
# Out:
# [('a',   key1 key2     data1     data2
#   0    a  one  0.163722 -0.103074
#   1    a  two -0.869117 -0.948556
#   4    a  one  0.916455 -0.547168), ('b',   key1 key2     data1     data2
#   2    b  one -1.768771 -0.713723
#   3    b  two  0.455637  0.137741)]

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one -1.768771 -0.713723
# 3    b  two  0.455637  0.137741

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
for dtype, group in grouped:
  print(dtype)
  print(group)
# Out:
# a
# 0    0.163722
# 1   -0.869117
# 4    0.916455
# Name: data1, dtype: float64
# b
# 2   -1.768771
# 3    0.455637
# Name: data1, dtype: float64

# %%
df.groupby('key1')['data1']

# %%
df.groupby('key1')[['data2']]

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one  -0.325121
#      two  -0.948556
# b    one  -0.713723
#      two   0.137741

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']

# %%
s_grouped.mean()
# Out:
# key1  key2
# a     one    -0.325121
#       two    -0.948556
# b     one    -0.713723
#       two     0.137741
# Name: data2, dtype: float64

# %%
people = pd.DataFrame(np.random.randn(5, 5),
 columns=['a', 'b', 'c', 'd', 'e'],
 index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

# %%
people.iloc[2:3, [1, 2]] = np.nan

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.811429  1.327609  0.057284 -0.883437 -0.298356
# Steve   1.148197  1.209433 -0.136133 -1.757792 -0.763123
# Wes     1.646511       NaN       NaN -0.605704 -0.370064
# Jim    -0.346506  1.099528 -1.218734  0.077741  1.060819
# Travis  1.201932  1.838076 -0.573149  0.194598 -0.047851

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
'd': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
by_column = people.groupby(mapping, axis=1)

# %%
by_column.sum()
# Out:
#             blue       red
# Joe    -0.826152  1.840682
# Steve  -1.893924  1.594507
# Wes    -0.605704  1.276447
# Jim    -1.140993  1.813841
# Travis -0.378551  2.992158

# %%
map_series = pd.Series(mapping)

# %%
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series, axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  2.111434  2.427137 -1.161450 -1.411400  0.392399
# 5  1.148197  1.209433 -0.136133 -1.757792 -0.763123
# 6  1.201932  1.838076 -0.573149  0.194598 -0.047851

# %%
key_list = ['one', 'one', 'one', 'two', 'two']

# %%
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one  0.811429  1.327609  0.057284 -0.883437 -0.370064
#   two -0.346506  1.099528 -1.218734  0.077741  1.060819
# 5 one  1.148197  1.209433 -0.136133 -1.757792 -0.763123
# 6 two  1.201932  1.838076 -0.573149  0.194598 -0.047851

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
 [1, 3, 5, 1, 3]],
 names=['cty', 'tenor'])

# %%
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)

# %%
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      1.348661 -2.087678 -1.188799 -2.667819 -0.688247
# 1      0.666307  0.044017 -0.454804 -0.144580  1.399269
# 2      1.203670 -1.685714  1.475714  1.016389 -0.069001
# 3      2.454916  0.245143 -0.662255  0.281621  0.824365

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.163722 -0.103074
# 1    a  two -0.869117 -0.948556
# 2    b  one -1.768771 -0.713723
# 3    b  two  0.455637  0.137741
# 4    a  one  0.916455 -0.547168

# %%
grouped = df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.765909
# b    0.233196
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
  return arr.max() - arr.min()

# %%
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     1.785573  0.845481
# b     2.224408  0.851465

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0  0.070353  0.896441 -0.869117 -0.352698  0.163722  0.540089
# b      2.0 -0.656567  1.572894 -1.768771 -1.212669 -0.656567 -0.100465
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     0.916455   3.0 -0.532933  0.422920 -0.948556 -0.747862 -0.547168
# b     0.455637   2.0 -0.287991  0.602076 -0.713723 -0.500857 -0.287991
#
#
#            75%       max
# key1
# a    -0.325121 -0.103074
# b    -0.075125  0.137741

# %%
tips = pd.read_csv('tips.csv')

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips[:6]
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808
# 5       25.29  4.71    Male     No  Sun  Dinner     4  0.186240

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
grouped_pct = grouped['tip_pct']
grouped_pct.agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
functions = ['count', 'mean', 'max']

# %%
grouped_pct.agg([('foo', 'mean'), ('bar', np.std)])
# Out:
#                   foo       bar
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
result = grouped['tip_pct', 'total_bill'].agg(functions)
result
# Out:
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
result['tip_pct']
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
ftuples = [('Durchschnitt', 'mean'), ('Abweichung', np.var)]

# %%
grouped['tip_pct', 'total_bill'].agg(ftuples)
# Out:
#                  tip_pct              total_bill
#             Durchschnitt Abweichung Durchschnitt  Abweichung
# day  smoker
# Fri  No         0.151650   0.000791    18.420000   25.596333
#      Yes        0.174783   0.002631    16.813333   82.562438
# Sat  No         0.158048   0.001581    19.661778   79.908965
#      Yes        0.147906   0.003767    21.276667  101.387535
# Sun  No         0.160113   0.001793    20.506667   66.099980
#      Yes        0.187250   0.023757    24.120000  109.046044
# Thur No         0.160298   0.001503    17.113111   59.625081
#      Yes        0.163863   0.001551    19.190588   69.808518

# %%
grouped.agg({'tip' : np.max, 'size' : 'sum'})
# Out:
#                tip  size
# day  smoker
# Fri  No       3.50     9
#      Yes      4.73    31
# Sat  No       9.00   115
#      Yes     10.00   104
# Sun  No       6.00   167
#      Yes      6.50    49
# Thur No       6.70   112
#      Yes      5.00    40

# %%
 grouped.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],
 'size' : 'sum'})
# Out:
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123    9
#      Yes     0.103555  0.263480  0.174783  0.051293   31
# Sat  No      0.056797  0.291990  0.158048  0.039767  115
#      Yes     0.035638  0.325733  0.147906  0.061375  104
# Sun  No      0.059447  0.252672  0.160113  0.042347  167
#      Yes     0.065660  0.710345  0.187250  0.154134   49
# Thur No      0.072961  0.266312  0.160298  0.038774  112
#      Yes     0.090014  0.241255  0.163863  0.039389   40

# %%
tips.groupby(['day', 'smoker'], as_index=False).mean()
# Out:
#     day smoker  total_bill       tip      size   tip_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %%
 def top(df, n=5, column='tip_pct'):
   return df.sort_values(by=column)[-n:]

# %%
top(tips, n=6)
# Out:
#      total_bill   tip     sex smoker  day    time  size   tip_pct
# 109       14.31  4.00  Female    Yes  Sat  Dinner     2  0.279525
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  0.280535
# 232       11.61  3.39    Male     No  Sat  Dinner     2  0.291990
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345

# %%
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip     sex smoker   day    time  size   tip_pct
# smoker
# No     88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
#        185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
#        51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
#        149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
#        232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# Yes    109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
#        183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
#        67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
#        178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
#        172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
# Out:
#                  total_bill    tip     sex smoker   day    time  size  \
# smoker day
# No     Fri  94        22.75   3.25  Female     No   Fri  Dinner     2
#        Sat  212       48.33   9.00    Male     No   Sat  Dinner     4
#        Sun  156       48.17   5.00    Male     No   Sun  Dinner     6
#        Thur 142       41.19   5.00    Male     No  Thur   Lunch     5
# Yes    Fri  95        40.17   4.73    Male    Yes   Fri  Dinner     4
#        Sat  170       50.81  10.00    Male    Yes   Sat  Dinner     3
#        Sun  182       45.35   3.50    Male    Yes   Sun  Dinner     3
#        Thur 197       43.11   5.00  Female    Yes  Thur   Lunch     4
#
#                   tip_pct
# smoker day
# No     Fri  94   0.142857
#        Sat  212  0.186220
#        Sun  156  0.103799
#        Thur 142  0.121389
# Yes    Fri  95   0.117750
#        Sat  170  0.196812
#        Sun  182  0.077178
#        Thur 197  0.115982

# %%
result = tips.groupby('smoker')['tip_pct'].describe()

# %%
result
# Out:
#         count      mean       std       min       25%       50%       75%  \
# smoker
# No      151.0  0.159328  0.039910  0.056797  0.136906  0.155625  0.185014
# Yes      93.0  0.163196  0.085119  0.035638  0.106771  0.153846  0.195059
#
#              max
# smoker
# No      0.291990
# Yes     0.710345

# %%
result.unstack('smoker')
# Out:
#        smoker
# count  No        151.000000
#        Yes        93.000000
# mean   No          0.159328
#        Yes         0.163196
# std    No          0.039910
#        Yes         0.085119
# min    No          0.056797
#        Yes         0.035638
# 25%    No          0.136906
#        Yes         0.106771
# 50%    No          0.155625
#        Yes         0.153846
# 75%    No          0.185014
#        Yes         0.195059
# max    No          0.291990
#        Yes         0.710345
# dtype: float64

# %%
f = lambda x: x.describe()
grouped.apply(f)
# Out:
#                    total_bill        tip       size    tip_pct
# day  smoker
# Fri  No     count    4.000000   4.000000   4.000000   4.000000
#             mean    18.420000   2.812500   2.250000   0.151650
#             std      5.059282   0.898494   0.500000   0.028123
#             min     12.460000   1.500000   2.000000   0.120385
#             25%     15.100000   2.625000   2.000000   0.137239
#             50%     19.235000   3.125000   2.000000   0.149241
#             75%     22.555000   3.312500   2.250000   0.163652
#             max     22.750000   3.500000   3.000000   0.187735
#      Yes    count   15.000000  15.000000  15.000000  15.000000
#             mean    16.813333   2.714000   2.066667   0.174783
#             std      9.086388   1.077668   0.593617   0.051293
#             min      5.750000   1.000000   1.000000   0.103555
#             25%     11.690000   1.960000   2.000000   0.133739
#             50%     13.420000   2.500000   2.000000   0.173913
#             75%     18.665000   3.240000   2.000000   0.209240
#             max     40.170000   4.730000   4.000000   0.263480
# Sat  No     count   45.000000  45.000000  45.000000  45.000000
#             mean    19.661778   3.102889   2.555556   0.158048
#             std      8.939181   1.642088   0.784960   0.039767
#             min      7.250000   1.000000   1.000000   0.056797
#             25%     14.730000   2.010000   2.000000   0.136240
#             50%     17.820000   2.750000   2.000000   0.150152
#             75%     20.650000   3.390000   3.000000   0.183915
#             max     48.330000   9.000000   4.000000   0.291990
#      Yes    count   42.000000  42.000000  42.000000  42.000000
#             mean    21.276667   2.875476   2.476190   0.147906
#             std     10.069138   1.630580   0.862161   0.061375
#             min      3.070000   1.000000   1.000000   0.035638
#             25%     13.405000   2.000000   2.000000   0.091797
#             50%     20.390000   2.690000   2.000000   0.153624
# ...                       ...        ...        ...        ...
# Sun  No     std      8.130189   1.224785   1.032674   0.042347
#             min      8.770000   1.010000   2.000000   0.059447
#             25%     14.780000   2.000000   2.000000   0.139780
#             50%     18.430000   3.020000   3.000000   0.161665
#             75%     25.000000   3.920000   4.000000   0.185185
#             max     48.170000   6.000000   6.000000   0.252672
#      Yes    count   19.000000  19.000000  19.000000  19.000000
#             mean    24.120000   3.516842   2.578947   0.187250
#             std     10.442511   1.261151   0.901591   0.154134
#             min      7.250000   1.500000   2.000000   0.065660
#             25%     17.165000   3.000000   2.000000   0.097723
#             50%     23.100000   3.500000   2.000000   0.138122
#             75%     32.375000   4.000000   3.000000   0.215325
#             max     45.350000   6.500000   5.000000   0.710345
# Thur No     count   45.000000  45.000000  45.000000  45.000000
#             mean    17.113111   2.673778   2.488889   0.160298
#             std      7.721728   1.282964   1.179796   0.038774
#             min      7.510000   1.250000   1.000000   0.072961
#             25%     11.690000   1.800000   2.000000   0.137741
#             50%     15.950000   2.180000   2.000000   0.153492
#             75%     20.270000   3.000000   2.000000   0.184843
#             max     41.190000   6.700000   6.000000   0.266312
#      Yes    count   17.000000  17.000000  17.000000  17.000000
#             mean    19.190588   3.030000   2.352941   0.163863
#             std      8.355149   1.113491   0.701888   0.039389
#             min     10.340000   2.000000   2.000000   0.090014
#             25%     13.510000   2.000000   2.000000   0.148038
#             50%     16.470000   2.560000   2.000000   0.153846
#             75%     19.810000   4.000000   2.000000   0.194837
#             max     43.110000   5.000000   4.000000   0.241255
#
# [64 rows x 4 columns]

# %%
tips.groupby('smoker', group_keys=False).apply(top)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
# 185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
# 51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
# 149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345

# %%
frame = pd.DataFrame({'data1': np.random.randn(1000),
 'data2': np.random.randn(1000)})

# %%
quartiles = pd.cut(frame.data1, 4)

# %%
quartiles[:10]
# Out:
# 0     (-0.0141, 1.714]
# 1    (-1.743, -0.0141]
# 2     (-3.478, -1.743]
# 3    (-1.743, -0.0141]
# 4     (-0.0141, 1.714]
# 5     (-0.0141, 1.714]
# 6    (-1.743, -0.0141]
# 7     (-0.0141, 1.714]
# 8     (-0.0141, 1.714]
# 9    (-1.743, -0.0141]
# Name: data1, dtype: category
# Categories (4, interval[float64]): [(-3.478, -1.743] < (-1.743, -0.0141] < (-0.0141, 1.714] < (1.714, 3.443]]

# %%
def get_stats(group):
  return {'min': group.min(), 'max': group.max(),
          'count': group.count(), 'mean': group.mean()}

# %%
grouped = frame.data2.groupby(quartiles)

# %%
grouped.apply(get_stats).unstack()
# Out:
#                    count       max      mean       min
# data1
# (-3.478, -1.743]    54.0  2.641169 -0.106925 -2.311830
# (-1.743, -0.0141]  472.0  3.650650 -0.012561 -2.882079
# (-0.0141, 1.714]   434.0  2.696264 -0.004978 -3.352430
# (1.714, 3.443]      40.0  1.423703 -0.275438 -2.550515

# %%
grouping = pd.qcut(frame.data1, 10, labels=False)

# %%
grouped = frame.data2.groupby(grouping)

# %%
grouped.apply(get_stats).unstack()
# Out:
#        count       max      mean       min
# data1
# 0      100.0  3.650650 -0.011223 -2.329527
# 1      100.0  2.105134 -0.034950 -2.362468
# 2      100.0  2.121773 -0.116649 -2.092036
# 3      100.0  3.583001  0.061352 -2.882079
# 4      100.0  2.634400  0.021472 -2.435888
# 5      100.0  2.696264 -0.093669 -2.207656
# 6      100.0  2.555422  0.052651 -2.206306
# 7      100.0  2.454983  0.018164 -2.489718
# 8      100.0  2.449593 -0.091034 -3.352430
# 9      100.0  2.283948 -0.054922 -2.550515

# %%
s = pd.Series(np.random.randn(6))

# %%
s[::2] = np.nan

# %%
s
# Out:
# 0         NaN
# 1    1.082942
# 2         NaN
# 3    1.106851
# 4         NaN
# 5   -1.243428
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    0.315455
# 1    1.082942
# 2    0.315455
# 3    1.106851
# 4    0.315455
# 5   -1.243428
# dtype: float64

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
  'Oregon', 'Nevada', 'California', 'Idaho']

# %%
group_key = ['East'] * 4 + ['West'] * 4

# %%
data = pd.Series(np.random.randn(8), index=states)

# %%
data
# Out:
# Ohio          1.627580
# New York      0.544629
# Vermont      -1.486238
# Florida      -0.568070
# Oregon        1.897730
# Nevada        0.375914
# California   -0.637072
# Idaho         1.200833
# dtype: float64

# %%
data[['Vermont', 'Nevada', 'Idaho']] = np.nan

# %%
data
# Out:
# Ohio          1.627580
# New York      0.544629
# Vermont            NaN
# Florida      -0.568070
# Oregon        1.897730
# Nevada             NaN
# California   -0.637072
# Idaho              NaN
# dtype: float64

# %%
data.groupby(group_key).mean()
# Out:
# East    0.534713
# West    0.630329
# dtype: float64

# %%
fill_mean = lambda g: g.fillna(g.mean())

# %%
data.groupby(group_key).apply(fill_mean)
# Out:
# Ohio          1.627580
# New York      0.544629
# Vermont       0.534713
# Florida      -0.568070
# Oregon        1.897730
# Nevada        0.630329
# California   -0.637072
# Idaho         0.630329
# dtype: float64

# %%
fill_values = {'East': 0.5, 'West': -1}

# %%
fill_func = lambda g: g.fillna(fill_values[g.name])

# %%
data.groupby(group_key).apply(fill_func)
# Out:
# Ohio          1.627580
# New York      0.544629
# Vermont       0.500000
# Florida      -0.568070
# Oregon        1.897730
# Nevada       -1.000000
# California   -0.637072
# Idaho        -1.000000
# dtype: float64

# %%
suits = ['H', 'S', 'C', 'D']
card_val = (list(range(1, 11)) + [10] * 3) * 4
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in ['H', 'S', 'C', 'D']:
  cards.extend(str(num) + suit for num in base_names)
deck = pd.Series(card_val, index=cards)

# %%
deck[:13]
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck, n=5):
   return deck.sample(n)

# %%
draw(deck)
# Out:
# 5D    5
# AC    1
# 9H    9
# 3D    3
# 9D    9
# dtype: int64

# %%
get_suit = lambda card: card[-1]

# %%
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  QC    10
#    2C     2
# D  KD    10
#    8D     8
# H  JH    10
#    3H     3
# S  6S     6
#    AS     1
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)
# Out:
# 9C      9
# AC      1
# QD     10
# 10D    10
# 4H      4
# 2H      2
# QS     10
# 4S      4
# dtype: int64

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a',
 'b', 'b', 'b', 'b'],
 'data': np.random.randn(8),
 'weights': np.random.rand(8)})

# %%
df
# Out:
#   category      data   weights
# 0        a  0.967922  0.252209
# 1        a -0.046190  0.643367
# 2        a -0.872101  0.135112
# 3        a -0.375119  0.998411
# 4        b -1.051538  0.059457
# 5        b  0.702661  0.787569
# 6        b  0.991191  0.145544
# 7        b -0.256978  0.389390

# %%
grouped = df.groupby('category')

# %%
get_wavg = lambda g: np.average(g['data'], weights=g['weights'])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a   -0.136983
# b    0.387182
# dtype: float64

# %%
close_px = pd.read_csv('stock_px.csv', parse_dates=True,index_col=0)

# %%
close_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5472 entries, 1990-02-01 to 2011-10-14
# Data columns (total 9 columns):
# AA      5472 non-null float64
# AAPL    5472 non-null float64
# GE      5472 non-null float64
# IBM     5472 non-null float64
# JNJ     5472 non-null float64
# MSFT    5472 non-null float64
# PEP     5471 non-null float64
# SPX     5472 non-null float64
# XOM     5472 non-null float64
# dtypes: float64(9)
# memory usage: 427.5 KB

# %%
close_px[-4:]
# Out:
#                AA    AAPL     GE     IBM    JNJ   MSFT    PEP      SPX    XOM
# 2011-10-11  10.30  400.29  16.14  185.00  63.96  27.00  60.95  1195.54  76.27
# 2011-10-12  10.05  402.19  16.40  186.12  64.33  26.96  62.70  1207.25  77.16
# 2011-10-13  10.10  408.43  16.22  186.82  64.23  27.18  62.36  1203.66  76.37
# 2011-10-14  10.26  422.00  16.60  190.53  64.72  27.27  62.24  1224.58  78.11

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
rets = close_px.pct_change().dropna()

# %%
get_year = lambda x: x.year

# %%
by_year = rets.groupby(get_year)

# %%
by_year.apply(spx_corr)
# Out:
